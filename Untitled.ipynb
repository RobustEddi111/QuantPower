# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import re
# ----> 3 import constant.CONSTANT
#       4 import os
#       6 def delete_row(inputFile, sheetName, outputFile):
#       7     # 读取 Excel 文件并选择指定工作表
#
# ModuleNotFoundError: No module named 'constant'
