# %%
# 数据读取代码
import pandas as pd
from datetime import datetime

# 读取气象数据
df_weather = pd.read_excel("D:\\工作\\特变电工\\13项目\\电价预测\\数据源\\open-meteo-40.11N113.32E1049m.xlsx",skiprows=12, header=0)
df_weather=df_weather.drop(df_weather.columns[[5,6]],axis=1)
# 处理时间列
df_weather['datetime'] = pd.to_datetime(df_weather['time'])
# 定义地区location_id 对应的权重
weights = {
    0: 0.1,
    1: 0.1,
    2: 0.1,
    3: 0.1,
    4: 0.1,
    5: 0.1,
    6: 0.1,
    7: 0.1,
    8: 0.1,
    9: 0.1
}
df_weather['权重']=df_weather["location_id"].map(weights)
df_weather["加权温度数据(°C)"] = df_weather["temperature_2m (°C)"] * df_weather['权重']
df_weather["加权100米风速数据（m/s）"] = df_weather["wind_speed_100m (m/s)"] * df_weather['权重']
df_weather["加权辐照度（W/m²）"] = df_weather["shortwave_radiation (W/m²)"] * df_weather['权重']

df_weather_groupedbyDate=df_weather.groupby('datetime')[["加权温度数据(°C)","加权100米风速数据（m/s）","加权辐照度（W/m²）"]].sum()
# df_weather_groupedbyDate = df_weather_groupedbyDate[df_weather_groupedbyDate.index >= '2022-01-01']
# df_weather_groupedbyDate
# Out:
#                      加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）
# datetime
# 2021-01-01 00:00:00      -10.85            4.492          0.0
# 2021-01-01 01:00:00      -10.75            4.385          0.0
# 2021-01-01 02:00:00      -10.71            4.253          0.0
# 2021-01-01 03:00:00      -10.55            4.134          0.0
# 2021-01-01 04:00:00      -10.61            4.010          0.0
# ...                         ...              ...          ...
# 2024-12-31 19:00:00       -0.74            2.599          0.0
# 2024-12-31 20:00:00       -1.36            2.538          0.0
# 2024-12-31 21:00:00       -2.15            2.420          0.0
# 2024-12-31 22:00:00       -2.87            2.278          0.0
# 2024-12-31 23:00:00       -3.51            2.019          0.0
#
# [35064 rows x 3 columns]

# %%
# 将1小时分辨率气象数据转换为15min
df_weather_groupedbyDate_resampled=df_weather_groupedbyDate.resample('15T').mean().interpolate(method='linear')  # 将数据重采样到15分钟,线性插值填补缺失值 
# df_weather_groupedbyDate_resampled
# Out:
#                      加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）
# datetime
# 2021-01-01 00:00:00     -10.850          4.49200          0.0
# 2021-01-01 00:15:00     -10.825          4.46525          0.0
# 2021-01-01 00:30:00     -10.800          4.43850          0.0
# 2021-01-01 00:45:00     -10.775          4.41175          0.0
# 2021-01-01 01:00:00     -10.750          4.38500          0.0
# ...                         ...              ...          ...
# 2024-12-31 22:00:00      -2.870          2.27800          0.0
# 2024-12-31 22:15:00      -3.030          2.21325          0.0
# 2024-12-31 22:30:00      -3.190          2.14850          0.0
# 2024-12-31 22:45:00      -3.350          2.08375          0.0
# 2024-12-31 23:00:00      -3.510          2.01900          0.0
#
# [140253 rows x 3 columns]

# %%
# 读取供需数据
df_DS = pd.read_excel("D:\\工作\\特变电工\\13项目\\电价预测\\数据源\\公有数据-供需数据-日前（2022-01-01至2024-12-31）.xlsx", header=0)

# %%
# 读取电价数据
df_Price = pd.read_excel("D:\\工作\\特变电工\\13项目\\电价预测\\数据源\\公有数据-出清量价（2022-01-01至2024-12-31）.xlsx",header=0)

# %%
df_DS
# 将 '日期' 和 '时间' 列合并为 datetime 并设为索引
df_DS['时间'] = df_DS['时间'].replace('24:00', '00:00')
df_DS['datetime'] = pd.to_datetime(df_DS['日期'] + ' ' + df_DS['时间'])
df_DS = df_DS.set_index('datetime')

# 删除原 '日期' 和 '时间' 列（可选）
df_DS = df_DS.drop(columns=['日期', '时间'])
# df_DS
# Out:
#                      竞价空间-日前\n（MW）  省调负荷-日前\n（MW）  联络线计划-日前\n（MW）  \
# datetime
# 2022-01-01 00:15:00       22261.65       28969.40         -4811.0
# 2022-01-01 00:30:00       22022.44       28939.50         -4811.0
# 2022-01-01 00:45:00       21771.57       28808.70         -4811.0
# 2022-01-01 01:00:00       21498.13       28655.00         -4811.0
# 2022-01-01 01:15:00       21215.71       28501.20         -4811.0
# ...                            ...            ...             ...
# 2024-12-31 23:00:00       33778.52       33559.90         -6244.0
# 2024-12-31 23:15:00       33307.81       33554.96         -5965.0
# 2024-12-31 23:30:00       32749.60       33035.02         -5965.0
# 2024-12-31 23:45:00       32354.82       32648.76         -5965.0
# 2024-12-31 00:00:00       33088.02       32779.51         -6594.0
#
#                      新能源出力-日前\n（MW）  光伏出力-日前\n（MW）  风电出力-日前\n（MW）  \
# datetime
# 2022-01-01 00:15:00        11518.75            0.0       11518.75
# 2022-01-01 00:30:00        11728.06            0.0       11728.06
# 2022-01-01 00:45:00        11848.13            0.0       11848.13
# 2022-01-01 01:00:00        11967.87            0.0       11967.87
# 2022-01-01 01:15:00        12096.49            0.0       12096.49
# ...                             ...            ...            ...
# 2024-12-31 23:00:00         6025.38            0.0        6025.38
# 2024-12-31 23:15:00         6212.15            0.0        6212.15
# 2024-12-31 23:30:00         6250.42            0.0        6250.42
# 2024-12-31 23:45:00         6258.94            0.0        6258.94
# 2024-12-31 00:00:00         6285.49            0.0        6285.49
#
#                      非市场化机组出力-日前\n（MW）
# datetime
# 2022-01-01 00:15:00               7025
# 2022-01-01 00:30:00               7017
# 2022-01-01 00:45:00               6950
# 2022-01-01 01:00:00               6853
# 2022-01-01 01:15:00               6945
# ...                                ...
# 2024-12-31 23:00:00               1134
# 2024-12-31 23:15:00               1134
# 2024-12-31 23:30:00               1134
# 2024-12-31 23:45:00               1134
# 2024-12-31 00:00:00               1134
#
# [105216 rows x 7 columns]

# %%
# df_Price
# 将 '日期' 和 '时间' 列合并为 datetime 并设为索引
df_Price['时间'] = df_Price['时间'].replace('24:00', '00:00')
df_Price['datetime'] = pd.to_datetime(df_Price['日期'] + ' ' + df_Price['时间'])
df_Price = df_Price.set_index('datetime')

# 删除原 '日期' 和 '时间' 列（可选）
df_Price = df_Price.drop(columns=['日期', '时间'])
# df_Price
# Out:
#                      统一出清价格-日前\n（元/MWh）  统一出清价格-实时\n（元/MWh）  现货出清电量-日前\n（MWh）  \
# datetime
# 2022-01-01 00:15:00                 0.0                 0.0           6871.00
# 2022-01-01 00:30:00                 0.0                 0.0           6754.00
# 2022-01-01 00:45:00                 0.0                 0.0           7608.00
# 2022-01-01 01:00:00                 0.0                 0.0           7322.00
# 2022-01-01 01:15:00                 0.0                 0.0           6099.00
# ...                                 ...                 ...               ...
# 2024-12-31 23:00:00               330.0               330.0           9300.25
# 2024-12-31 23:15:00               319.0               330.0           9061.00
# 2024-12-31 23:30:00               310.0               329.0           8907.25
# 2024-12-31 23:45:00               319.0               320.0           9061.50
# 2024-12-31 00:00:00               320.0               330.0           9132.25
#
#                      现货出清电量-实时\n（MWh）
# datetime
# 2022-01-01 00:15:00           1160.45
# 2022-01-01 00:30:00           1374.96
# 2022-01-01 00:45:00           1251.94
# 2022-01-01 01:00:00           1354.76
# 2022-01-01 01:15:00           1167.26
# ...                               ...
# 2024-12-31 23:00:00           9229.81
# 2024-12-31 23:15:00           9156.22
# 2024-12-31 23:30:00           9167.16
# 2024-12-31 23:45:00           9167.68
# 2024-12-31 00:00:00           9275.92
#
# [105216 rows x 4 columns]

# %%
# 截取共同时间段
start_time = max(df_weather_groupedbyDate.index.min(), df_DS.index.min(), df_Price.index.min())
end_time = min(df_weather_groupedbyDate.index.max(), df_DS.index.max(), df_Price.index.max())

df_weather_groupedbyDate_resampled = df_weather_groupedbyDate_resampled.loc[start_time:end_time]
df_DS = df_DS.loc[start_time:end_time]
df_Price = df_Price.loc[start_time:end_time]

# %%
# 合并并列出缺失数据及缺失行
merged_df = df_weather_groupedbyDate_resampled.merge(df_DS, on='datetime', how='outer').merge(df_Price, on='datetime', how='outer')
print(merged_df.isnull().sum())
missing_rows = merged_df[merged_df.isnull().any(axis=1)]
print(f"------------------------------------缺失行-----------------------------------------------------------------\n{missing_rows.head()}")
# 清洗数据
cleaned_merged_df= merged_df.dropna()
cleaned_merged_df
# Out:
# 加权温度数据(°C)              0
# 加权100米风速数据（m/s）         0
# 加权辐照度（W/m²）             0
# 竞价空间-日前\n（MW）          96
# 省调负荷-日前\n（MW）          96
# 联络线计划-日前\n（MW）         96
# 新能源出力-日前\n（MW）         96
# 光伏出力-日前\n（MW）          96
# 风电出力-日前\n（MW）          96
# 非市场化机组出力-日前\n（MW）      96
# 统一出清价格-日前\n（元/MWh）     96
# 统一出清价格-实时\n（元/MWh）     96
# 现货出清电量-日前\n（MWh）      192
# 现货出清电量-实时\n（MWh）       96
# dtype: int64
# ------------------------------------缺失行-----------------------------------------------------------------
#                      加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）  竞价空间-日前\n（MW）  \
# datetime
# 2022-01-01 00:15:00     -3.8875          2.68975          0.0            NaN
# 2022-01-01 00:30:00     -3.9750          2.67350          0.0            NaN
# 2022-01-01 00:45:00     -4.0625          2.65725          0.0            NaN
# 2022-01-01 01:00:00     -4.1500          2.64100          0.0            NaN
# 2022-01-01 01:15:00     -4.2825          2.72525          0.0            NaN
#
#                      省调负荷-日前\n（MW）  联络线计划-日前\n（MW）  新能源出力-日前\n（MW）  \
# datetime
# 2022-01-01 00:15:00            NaN             NaN             NaN
# 2022-01-01 00:30:00            NaN             NaN             NaN
# 2022-01-01 00:45:00            NaN             NaN             NaN
# 2022-01-01 01:00:00            NaN             NaN             NaN
# 2022-01-01 01:15:00            NaN             NaN             NaN
#
#                      光伏出力-日前\n（MW）  风电出力-日前\n（MW）  非市场化机组出力-日前\n（MW）  \
# datetime
# 2022-01-01 00:15:00            NaN            NaN                NaN
# 2022-01-01 00:30:00            NaN            NaN                NaN
# 2022-01-01 00:45:00            NaN            NaN                NaN
# 2022-01-01 01:00:00            NaN            NaN                NaN
# 2022-01-01 01:15:00            NaN            NaN                NaN
#
#                      统一出清价格-日前\n（元/MWh）  统一出清价格-实时\n（元/MWh）  现货出清电量-日前\n（MWh）  \
# datetime
# 2022-01-01 00:15:00                 NaN                 NaN               NaN
# 2022-01-01 00:30:00                 NaN                 NaN               NaN
# 2022-01-01 00:45:00                 NaN                 NaN               NaN
# 2022-01-01 01:00:00                 NaN                 NaN               NaN
# 2022-01-01 01:15:00                 NaN                 NaN               NaN
#
#                      现货出清电量-实时\n（MWh）
# datetime
# 2022-01-01 00:15:00               NaN
# 2022-01-01 00:30:00               NaN
# 2022-01-01 00:45:00               NaN
# 2022-01-01 01:00:00               NaN
# 2022-01-01 01:15:00               NaN
#                      加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）  竞价空间-日前\n（MW）  \
# datetime
# 2022-01-01 00:00:00     -3.8000          2.70600          0.0       29551.10
# 2022-01-02 00:00:00     -5.4600          2.20100          0.0       25314.33
# 2022-01-02 00:15:00     -5.6875          2.14925          0.0       32217.60
# 2022-01-02 00:30:00     -5.9150          2.09750          0.0       32157.26
# 2022-01-02 00:45:00     -6.1425          2.04575          0.0       32120.49
# ...                         ...              ...          ...            ...
# 2024-12-31 22:00:00     -2.8700          2.27800          0.0       36318.48
# 2024-12-31 22:15:00     -3.0300          2.21325          0.0       36335.12
# 2024-12-31 22:30:00     -3.1900          2.14850          0.0       35378.85
# 2024-12-31 22:45:00     -3.3500          2.08375          0.0       34734.20
# 2024-12-31 23:00:00     -3.5100          2.01900          0.0       33778.52
#
#                      省调负荷-日前\n（MW）  联络线计划-日前\n（MW）  新能源出力-日前\n（MW）  \
# datetime
# 2022-01-01 00:00:00       28894.50         -4626.0         3969.40
# 2022-01-02 00:00:00       29325.50         -5610.0         9621.17
# 2022-01-02 00:15:00       29085.70         -5610.0         2478.10
# 2022-01-02 00:30:00       28936.90         -5610.0         2389.64
# 2022-01-02 00:45:00       28822.00         -5610.0         2311.51
# ...                            ...             ...             ...
# 2024-12-31 22:00:00       34927.07         -6784.5         5393.09
# 2024-12-31 22:15:00       34813.73         -7015.1         5493.71
# 2024-12-31 22:30:00       34179.26         -6755.7         5556.11
# 2024-12-31 22:45:00       33950.80         -6499.4         5716.00
# 2024-12-31 23:00:00       33559.90         -6244.0         6025.38
#
#                      光伏出力-日前\n（MW）  风电出力-日前\n（MW）  非市场化机组出力-日前\n（MW）  \
# datetime
# 2022-01-01 00:00:00            1.1        3968.30             6953.0
# 2022-01-02 00:00:00            1.6        9619.57             7118.0
# 2022-01-02 00:15:00            0.0        2478.10             6938.0
# 2022-01-02 00:30:00            0.0        2389.64             6887.0
# 2022-01-02 00:45:00            0.0        2311.51             6893.0
# ...                            ...            ...                ...
# 2024-12-31 22:00:00            0.0        5393.09             1137.0
# 2024-12-31 22:15:00            0.0        5493.71             1137.0
# 2024-12-31 22:30:00            0.0        5556.11             1134.0
# 2024-12-31 22:45:00            0.0        5716.00             1134.0
# 2024-12-31 23:00:00            0.0        6025.38             1134.0
#
#                      统一出清价格-日前\n（元/MWh）  统一出清价格-实时\n（元/MWh）  现货出清电量-日前\n（MWh）  \
# datetime
# 2022-01-01 00:00:00               340.0              376.00           2066.00
# 2022-01-02 00:00:00                 0.0                2.00           3246.00
# 2022-01-02 00:15:00               368.0              370.00           6661.00
# 2022-01-02 00:30:00               362.0              389.00           6021.00
# 2022-01-02 00:45:00               365.0              392.13           6308.00
# ...                                 ...                 ...               ...
# 2024-12-31 22:00:00               360.0              335.00           9813.50
# 2024-12-31 22:15:00               350.0              340.00           9700.50
# 2024-12-31 22:30:00               335.0              340.00           9466.25
# 2024-12-31 22:45:00               332.0              338.00           9420.75
# 2024-12-31 23:00:00               330.0              330.00           9300.25
#
#                      现货出清电量-实时\n（MWh）
# datetime
# 2022-01-01 00:00:00              0.00
# 2022-01-02 00:00:00              0.00
# 2022-01-02 00:15:00            934.05
# 2022-01-02 00:30:00            892.92
# 2022-01-02 00:45:00            983.11
# ...                               ...
# 2024-12-31 22:00:00           9679.55
# 2024-12-31 22:15:00           9714.28
# 2024-12-31 22:30:00           9540.37
# 2024-12-31 22:45:00           9437.89
# 2024-12-31 23:00:00           9229.81
#
# [105021 rows x 14 columns]

# %%
#  时间索引检查与修复，确保时间索引没有重复、空值、错误类型
cleaned_merged_df.index = pd.to_datetime(cleaned_merged_df.index)
cleaned_merged_df = cleaned_merged_df.sort_index()
assert cleaned_merged_df.index.is_monotonic_increasing
cleaned_merged_df.columns
# Out:
# Index(['加权温度数据(°C)', '加权100米风速数据（m/s）', '加权辐照度（W/m²）', '竞价空间-日前\n（MW）',
#        '省调负荷-日前\n（MW）', '联络线计划-日前\n（MW）', '新能源出力-日前\n（MW）', '光伏出力-日前\n（MW）',
#        '风电出力-日前\n（MW）', '非市场化机组出力-日前\n（MW）', '统一出清价格-日前\n（元/MWh）',
#        '统一出清价格-实时\n（元/MWh）', '现货出清电量-日前\n（MWh）', '现货出清电量-实时\n（MWh）'],
#       dtype='object')

# %%
# 【电价滞后特征】先把目标电价列赋给一个变量方便操作，增加滞后特征
price_col = '统一出清价格-日前\n（元/MWh）'

# 创建滞后特征，lag 1小时，2小时，3小时（对应4, 8, 12个时间步长）
cleaned_merged_df[f'{price_col}_lag_1h'] = cleaned_merged_df[price_col].shift(4)
cleaned_merged_df[f'{price_col}_lag_2h'] = cleaned_merged_df[price_col].shift(8)
cleaned_merged_df[f'{price_col}_lag_3h'] = cleaned_merged_df[price_col].shift(12)

# %%
# 【周期特征、星期特征、节假日特征】

cleaned_merged_df['weekday'] = cleaned_merged_df.index.weekday          # 星期几，0=周一，6=周日
cleaned_merged_df['weekofyear'] = cleaned_merged_df.index.isocalendar().week  # 第几周（ISO周数）

# 节假日特征（需用节假日包）
import holidays

# 这里以中国假期为例
cn_holidays = holidays.China()

cleaned_merged_df['is_holiday'] = cleaned_merged_df.index.to_series().apply(lambda x: 1 if x in cn_holidays else 0)

# %%
cleaned_merged_df = cleaned_merged_df.dropna()
cleaned_merged_df
# Out:
#                      加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）  竞价空间-日前\n（MW）  \
# datetime
# 2022-01-02 02:45:00      -6.595          1.99425          0.0       31666.75
# 2022-01-02 03:00:00      -6.570          2.07900          0.0       31637.90
# 2022-01-02 03:15:00      -6.645          2.08750          0.0       31622.48
# 2022-01-02 03:30:00      -6.720          2.09600          0.0       31579.72
# 2022-01-02 03:45:00      -6.795          2.10450          0.0       31560.86
# ...                         ...              ...          ...            ...
# 2024-12-31 22:00:00      -2.870          2.27800          0.0       36318.48
# 2024-12-31 22:15:00      -3.030          2.21325          0.0       36335.12
# 2024-12-31 22:30:00      -3.190          2.14850          0.0       35378.85
# 2024-12-31 22:45:00      -3.350          2.08375          0.0       34734.20
# 2024-12-31 23:00:00      -3.510          2.01900          0.0       33778.52
#
#                      省调负荷-日前\n（MW）  联络线计划-日前\n（MW）  新能源出力-日前\n（MW）  \
# datetime
# 2022-01-02 02:45:00       28052.70         -5610.0         1995.95
# 2022-01-02 03:00:00       28017.00         -5610.0         1989.10
# 2022-01-02 03:15:00       27996.30         -5610.0         1983.82
# 2022-01-02 03:30:00       27969.90         -5610.0         2000.18
# 2022-01-02 03:45:00       27982.70         -5610.0         2031.84
# ...                            ...             ...             ...
# 2024-12-31 22:00:00       34927.07         -6784.5         5393.09
# 2024-12-31 22:15:00       34813.73         -7015.1         5493.71
# 2024-12-31 22:30:00       34179.26         -6755.7         5556.11
# 2024-12-31 22:45:00       33950.80         -6499.4         5716.00
# 2024-12-31 23:00:00       33559.90         -6244.0         6025.38
#
#                      光伏出力-日前\n（MW）  风电出力-日前\n（MW）  非市场化机组出力-日前\n（MW）  \
# datetime
# 2022-01-02 02:45:00            0.0        1995.95             7014.0
# 2022-01-02 03:00:00            0.0        1989.10             7026.0
# 2022-01-02 03:15:00            0.0        1983.82             7084.0
# 2022-01-02 03:30:00            0.0        2000.18             7086.0
# 2022-01-02 03:45:00            0.0        2031.84             7047.0
# ...                            ...            ...                ...
# 2024-12-31 22:00:00            0.0        5393.09             1137.0
# 2024-12-31 22:15:00            0.0        5493.71             1137.0
# 2024-12-31 22:30:00            0.0        5556.11             1134.0
# 2024-12-31 22:45:00            0.0        5716.00             1134.0
# 2024-12-31 23:00:00            0.0        6025.38             1134.0
#
#                      统一出清价格-日前\n（元/MWh）  统一出清价格-实时\n（元/MWh）  现货出清电量-日前\n（MWh）  \
# datetime
# 2022-01-02 02:45:00               359.0              360.00           6037.00
# 2022-01-02 03:00:00               358.0              380.00           6873.00
# 2022-01-02 03:15:00               358.0              384.03           6266.00
# 2022-01-02 03:30:00               355.0              380.00           6394.00
# 2022-01-02 03:45:00               355.0              380.00           7080.00
# ...                                 ...                 ...               ...
# 2024-12-31 22:00:00               360.0              335.00           9813.50
# 2024-12-31 22:15:00               350.0              340.00           9700.50
# 2024-12-31 22:30:00               335.0              340.00           9466.25
# 2024-12-31 22:45:00               332.0              338.00           9420.75
# 2024-12-31 23:00:00               330.0              330.00           9300.25
#
#                      现货出清电量-实时\n（MWh）  统一出清价格-日前\n（元/MWh）_lag_1h  \
# datetime
# 2022-01-02 02:45:00           1164.39                      365.0
# 2022-01-02 03:00:00           1199.44                      360.0
# 2022-01-02 03:15:00           1039.17                      362.0
# 2022-01-02 03:30:00           1221.46                      360.0
# 2022-01-02 03:45:00            848.75                      359.0
# ...                               ...                        ...
# 2024-12-31 22:00:00           9679.55                      349.0
# 2024-12-31 22:15:00           9714.28                      360.0
# 2024-12-31 22:30:00           9540.37                      360.0
# 2024-12-31 22:45:00           9437.89                      365.0
# 2024-12-31 23:00:00           9229.81                      360.0
#
#                      统一出清价格-日前\n（元/MWh）_lag_2h  统一出清价格-日前\n（元/MWh）_lag_3h
# datetime
# 2022-01-02 02:45:00                      365.0                     340.00
# 2022-01-02 03:00:00                      366.0                       0.00
# 2022-01-02 03:15:00                      370.0                     368.00
# 2022-01-02 03:30:00                      365.0                     362.00
# 2022-01-02 03:45:00                      365.0                     365.00
# ...                                        ...                        ...
# 2024-12-31 22:00:00                      349.0                     365.00
# 2024-12-31 22:15:00                      360.0                     360.00
# 2024-12-31 22:30:00                      338.0                     350.00
# 2024-12-31 22:45:00                      349.0                     344.89
# 2024-12-31 23:00:00                      349.0                     349.00
#
# [105009 rows x 17 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置字体为 SimHei
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %%
# 计算相关性矩阵
correlation_matrix = cleaned_merged_df.corr()

# 输出相关性矩阵
print("山西20220101-20241231相关性矩阵:")
print(correlation_matrix)

# 可视化相关性矩阵
plt.figure(figsize=(10, 8))
sns.set(font='SimHei')  # 使用 SimHei 字体

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('山西20220101-20241231相关性矩阵:')
plt.show()
# Out:
# 山西20220101-20241231相关性矩阵:
#                            加权温度数据(°C)  加权100米风速数据（m/s）  加权辐照度（W/m²）  \
# 加权温度数据(°C)                   1.000000         0.022050     0.436904
# 加权100米风速数据（m/s）              0.022050         1.000000     0.001656
# 加权辐照度（W/m²）                  0.436904         0.001656     1.000000
# 竞价空间-日前\n（MW）               -0.190567        -0.366278    -0.466156
# 省调负荷-日前\n（MW）               -0.423611         0.052707    -0.275112
# 联络线计划-日前\n（MW）              -0.011234         0.078790    -0.276041
# 新能源出力-日前\n（MW）              -0.018360         0.472981     0.533947
# 光伏出力-日前\n（MW）                0.279929        -0.043034     0.904070
# 风电出力-日前\n（MW）               -0.271258         0.656615    -0.100168
# 非市场化机组出力-日前\n（MW）            0.094301         0.007167     0.028756
# 统一出清价格-日前\n（元/MWh）          -0.005668        -0.207520    -0.279515
# 统一出清价格-实时\n（元/MWh）          -0.043919        -0.200140    -0.254398
# 现货出清电量-日前\n（MWh）            -0.079826         0.005982    -0.092542
# 现货出清电量-实时\n（MWh）            -0.176947        -0.062470    -0.129134
# 统一出清价格-日前\n（元/MWh）_lag_1h   -0.019917        -0.240313    -0.273176
# 统一出清价格-日前\n（元/MWh）_lag_2h   -0.024118        -0.271741    -0.231293
# 统一出清价格-日前\n（元/MWh）_lag_3h   -0.021088        -0.293577    -0.173011
#
#                            竞价空间-日前\n（MW）  省调负荷-日前\n（MW）  联络线计划-日前\n（MW）  \
# 加权温度数据(°C)                     -0.190567      -0.423611       -0.011234
# 加权100米风速数据（m/s）                -0.366278       0.052707        0.078790
# 加权辐照度（W/m²）                    -0.466156      -0.275112       -0.276041
# 竞价空间-日前\n（MW）                   1.000000       0.654581       -0.276457
# 省调负荷-日前\n（MW）                   0.654581       1.000000       -0.275287
# 联络线计划-日前\n（MW）                 -0.276457      -0.275287        1.000000
# 新能源出力-日前\n（MW）                 -0.762582      -0.100864       -0.212573
# 光伏出力-日前\n（MW）                  -0.515824      -0.232589       -0.328261
# 风电出力-日前\n（MW）                  -0.541774       0.073514        0.011912
# 非市场化机组出力-日前\n（MW）               0.042894      -0.130292        0.167947
# 统一出清价格-日前\n（元/MWh）              0.627733       0.295074       -0.130813
# 统一出清价格-实时\n（元/MWh）              0.572189       0.266258       -0.102769
# 现货出清电量-日前\n（MWh）                0.245863       0.279336       -0.208030
# 现货出清电量-实时\n（MWh）                0.239162       0.310274       -0.397640
# 统一出清价格-日前\n（元/MWh）_lag_1h       0.596377       0.272680       -0.127739
# 统一出清价格-日前\n（元/MWh）_lag_2h       0.529175       0.211429       -0.126103
# 统一出清价格-日前\n（元/MWh）_lag_3h       0.448046       0.133958       -0.125742
#
#                            新能源出力-日前\n（MW）  光伏出力-日前\n（MW）  风电出力-日前\n（MW）  \
# 加权温度数据(°C)                      -0.018360       0.279929      -0.271258
# 加权100米风速数据（m/s）                  0.472981      -0.043034       0.656615
# 加权辐照度（W/m²）                      0.533947       0.904070      -0.100168
# 竞价空间-日前\n（MW）                   -0.762582      -0.515824      -0.541774
# 省调负荷-日前\n（MW）                   -0.100864      -0.232589       0.073514
# 联络线计划-日前\n（MW）                  -0.212573      -0.328261       0.011912
# 新能源出力-日前\n（MW）                   1.000000       0.645217       0.738005
# 光伏出力-日前\n（MW）                    0.645217       1.000000      -0.039369
# 风电出力-日前\n（MW）                    0.738005      -0.039369       1.000000
# 非市场化机组出力-日前\n（MW）               -0.203611      -0.112833      -0.166642
# 统一出清价格-日前\n（元/MWh）              -0.568722      -0.352119      -0.432819
# 统一出清价格-实时\n（元/MWh）              -0.526597      -0.315278      -0.410263
# 现货出清电量-日前\n（MWh）                -0.057505      -0.094882       0.008594
# 现货出清电量-实时\n（MWh）                 0.045345      -0.033387       0.088794
# 统一出清价格-日前\n（元/MWh）_lag_1h       -0.543787      -0.321325      -0.427405
# 统一出清价格-日前\n（元/MWh）_lag_2h       -0.496775      -0.260518      -0.419626
# 统一出清价格-日前\n（元/MWh）_lag_3h       -0.441612      -0.193054      -0.407066
#
#                            非市场化机组出力-日前\n（MW）  统一出清价格-日前\n（元/MWh）  \
# 加权温度数据(°C)                          0.094301           -0.005668
# 加权100米风速数据（m/s）                     0.007167           -0.207520
# 加权辐照度（W/m²）                         0.028756           -0.279515
# 竞价空间-日前\n（MW）                       0.042894            0.627733
# 省调负荷-日前\n（MW）                      -0.130292            0.295074
# 联络线计划-日前\n（MW）                      0.167947           -0.130813
# 新能源出力-日前\n（MW）                     -0.203611           -0.568722
# 光伏出力-日前\n（MW）                      -0.112833           -0.352119
# 风电出力-日前\n（MW）                      -0.166642           -0.432819
# 非市场化机组出力-日前\n（MW）                   1.000000            0.212719
# 统一出清价格-日前\n（元/MWh）                  0.212719            1.000000
# 统一出清价格-实时\n（元/MWh）                  0.186228            0.777199
# 现货出清电量-日前\n（MWh）                   -0.047039            0.121369
# 现货出清电量-实时\n（MWh）                   -0.728309           -0.035411
# 统一出清价格-日前\n（元/MWh）_lag_1h           0.210059            0.884163
# 统一出清价格-日前\n（元/MWh）_lag_2h           0.201006            0.752987
# 统一出清价格-日前\n（元/MWh）_lag_3h           0.187759            0.638443
#
#                            统一出清价格-实时\n（元/MWh）  现货出清电量-日前\n（MWh）  \
# 加权温度数据(°C)                          -0.043919         -0.079826
# 加权100米风速数据（m/s）                     -0.200140          0.005982
# 加权辐照度（W/m²）                         -0.254398         -0.092542
# 竞价空间-日前\n（MW）                        0.572189          0.245863
# 省调负荷-日前\n（MW）                        0.266258          0.279336
# 联络线计划-日前\n（MW）                      -0.102769         -0.208030
# 新能源出力-日前\n（MW）                      -0.526597         -0.057505
# 光伏出力-日前\n（MW）                       -0.315278         -0.094882
# 风电出力-日前\n（MW）                       -0.410263          0.008594
# 非市场化机组出力-日前\n（MW）                    0.186228         -0.047039
# 统一出清价格-日前\n（元/MWh）                   0.777199          0.121369
# 统一出清价格-实时\n（元/MWh）                   1.000000          0.120542
# 现货出清电量-日前\n（MWh）                     0.120542          1.000000
# 现货出清电量-实时\n（MWh）                     0.029608          0.162518
# 统一出清价格-日前\n（元/MWh）_lag_1h            0.708507          0.111726
# 统一出清价格-日前\n（元/MWh）_lag_2h            0.613273          0.093020
# 统一出清价格-日前\n（元/MWh）_lag_3h            0.522447          0.071429
#
#                            现货出清电量-实时\n（MWh）  统一出清价格-日前\n（元/MWh）_lag_1h  \
# 加权温度数据(°C)                        -0.176947                  -0.019917
# 加权100米风速数据（m/s）                   -0.062470                  -0.240313
# 加权辐照度（W/m²）                       -0.129134                  -0.273176
# 竞价空间-日前\n（MW）                      0.239162                   0.596377
# 省调负荷-日前\n（MW）                      0.310274                   0.272680
# 联络线计划-日前\n（MW）                    -0.397640                  -0.127739
# 新能源出力-日前\n（MW）                     0.045345                  -0.543787
# 光伏出力-日前\n（MW）                     -0.033387                  -0.321325
# 风电出力-日前\n（MW）                      0.088794                  -0.427405
# 非市场化机组出力-日前\n（MW）                 -0.728309                   0.210059
# 统一出清价格-日前\n（元/MWh）                -0.035411                   0.884163
# 统一出清价格-实时\n（元/MWh）                 0.029608                   0.708507
# 现货出清电量-日前\n（MWh）                   0.162518                   0.111726
# 现货出清电量-实时\n（MWh）                   1.000000                  -0.041211
# 统一出清价格-日前\n（元/MWh）_lag_1h         -0.041211                   1.000000
# 统一出清价格-日前\n（元/MWh）_lag_2h         -0.051493                   0.884163
# 统一出清价格-日前\n（元/MWh）_lag_3h         -0.062473                   0.752980
#
#                            统一出清价格-日前\n（元/MWh）_lag_2h  \
# 加权温度数据(°C)                                 -0.024118
# 加权100米风速数据（m/s）                            -0.271741
# 加权辐照度（W/m²）                                -0.231293
# 竞价空间-日前\n（MW）                               0.529175
# 省调负荷-日前\n（MW）                               0.211429
# 联络线计划-日前\n（MW）                             -0.126103
# 新能源出力-日前\n（MW）                             -0.496775
# 光伏出力-日前\n（MW）                              -0.260518
# 风电出力-日前\n（MW）                              -0.419626
# 非市场化机组出力-日前\n（MW）                           0.201006
# 统一出清价格-日前\n（元/MWh）                          0.752987
# 统一出清价格-实时\n（元/MWh）                          0.613273
# 现货出清电量-日前\n（MWh）                            0.093020
# 现货出清电量-实时\n（MWh）                           -0.051493
# 统一出清价格-日前\n（元/MWh）_lag_1h                   0.884163
# 统一出清价格-日前\n（元/MWh）_lag_2h                   1.000000
# 统一出清价格-日前\n（元/MWh）_lag_3h                   0.884153
#
#                            统一出清价格-日前\n（元/MWh）_lag_3h
# 加权温度数据(°C)                                 -0.021088
# 加权100米风速数据（m/s）                            -0.293577
# 加权辐照度（W/m²）                                -0.173011
# 竞价空间-日前\n（MW）                               0.448046
# 省调负荷-日前\n（MW）                               0.133958
# 联络线计划-日前\n（MW）                             -0.125742
# 新能源出力-日前\n（MW）                             -0.441612
# 光伏出力-日前\n（MW）                              -0.193054
# 风电出力-日前\n（MW）                              -0.407066
# 非市场化机组出力-日前\n（MW）                           0.187759
# 统一出清价格-日前\n（元/MWh）                          0.638443
# 统一出清价格-实时\n（元/MWh）                          0.522447
# 现货出清电量-日前\n（MWh）                            0.071429
# 现货出清电量-实时\n（MWh）                           -0.062473
# 统一出清价格-日前\n（元/MWh）_lag_1h                   0.752980
# 统一出清价格-日前\n（元/MWh）_lag_2h                   0.884153
# 统一出清价格-日前\n（元/MWh）_lag_3h                   1.000000
# C:\Users\96498\.conda\envs\myenv\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 178 (\N{SUPERSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# C:\Users\96498\.conda\envs\myenv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 178 (\N{SUPERSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
# 目标 & 特征列
target_col = '统一出清价格-日前\n（元/MWh）'

feature_cols = [
    '加权温度数据(°C)', '加权100米风速数据（m/s）', '加权辐照度（W/m²）',
    '竞价空间-日前\n（MW）', '省调负荷-日前\n（MW）', '联络线计划-日前\n（MW）',
    '新能源出力-日前\n（MW）', '光伏出力-日前\n（MW）', '风电出力-日前\n（MW）',
    '非市场化机组出力-日前\n（MW）', '现货出清电量-日前\n（MWh）',
    f'{price_col}_lag_1h', f'{price_col}_lag_2h', f'{price_col}_lag_3h'
]

# 构造 X 和 y
X = cleaned_merged_df[feature_cols]
y = cleaned_merged_df[target_col]
# 去除缺失
X = X.fillna(method='ffill').dropna()
y = y.loc[X.index]

# %%
# 拆分训练测试（按时间也可以）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# 模型训练
model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5)
model.fit(X_train, y_train)

# 预测
y_pred = model.predict(X_test)

# 评估
print("MAE:", 1-mean_absolute_error(y_test, y_pred)/np.mean(y_test))
print("RMSE:", 1-mean_squared_error(y_test, y_pred, squared=False)/np.mean(y_test))
# Out:
# MAE: 0.8751885898810815
# RMSE: 0.7533882095023644

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # Windows常用黑体
plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示问题
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label='真实电价')
plt.plot(y_pred, label='预测电价', linestyle='--')
plt.title('日前电价预测效果')
plt.xlabel('时间点（测试集）')
plt.ylabel('电价（元/MWh）')
plt.legend()
plt.grid(True)
plt.show()
