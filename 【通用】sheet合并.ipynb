# %%
import pandas as pd

# 读取 Excel 中所有 sheet
sheets = pd.read_excel("D:/工作/特变电工/08交易/疆内项目/交易决策/2025/8月/8月18日滚撮/8月1日-8月17日柯坪发电量数据（24点）(1).xlsx", sheet_name=None)

df_list = []

for sheet_name, df in sheets.items():
    # 在第一列插入 '简称' 列，值为 sheet 名
    # df.insert(0, "sheet简称", sheet_name)
    df_list.append(df)

# 合并所有 sheet
df_all = pd.concat(df_list, ignore_index=True)

# 保存结果
df_all.to_excel("D:/工作/特变电工/08交易/疆内项目/交易决策/2025/8月/8月18日滚撮/【合并】8月1日-8月17日柯坪发电量数据（24点）(1).xlsx", index=False)
