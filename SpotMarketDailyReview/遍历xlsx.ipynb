# %%
import pandas as pd
import re
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")



# 【循环处理文件夹内所有文件】
folder_path = "D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/"
output_path = "D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日复盘/4.0复盘/test1/"

for file in os.listdir(folder_path):
    file_path=os.path.join(folder_path, file)
    # 读取 Excel 文件（默认读取第一个 Sheet）
    if file.endswith(".xlsx"):
        df = pd.read_excel(file_path, engine="openpyxl")
        print(f"已读取文件：{file_path}")
        # df.columns= ["名称"]+[f"{i}:00" for i in range(1, 25)]+["合计"]
# Out:
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-01-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-02-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-03-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-04-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-05-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-06-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-07-明细.xlsx
# 已读取文件：D:/工作/特变电工/01_0政策与学习笔记/_全国_20250520/国网区域/新疆/400-交易复盘/现货日清分_系统导出数据/test1/哈密市振超风力发电有限公司2025-09-08-明细.xlsx
# ...
